# %%
import vaex as vx
import h5py
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd


# For dataset >1M+ use this
#vx_df = vx.open('/Users/khanh/UCSF/npr/raw_data/npr_mlsmr.hdf5') #change me
#npr_df = vx_df.to_pandas_df(["npr1", "npr2"])

#x = nprdf['npr1']
#y = npr_df['npr2']

#for smaller dataset there is not need to use vaex
df = pd.read_csv('/Users/khanh/UCSF/npr/data/mlsmr', sep='\s+') #change me
print(df['npr1'])
# grep only npr values   
x = df['npr1']
y = df['npr2']
mpl.rcParams['figure.dpi'] = 500
print('Plotting...')
# plot data with 1000x1000    , set color bar to base 10, color scheme  
plt.hist2d(x, y, (1000, 1000), norm=mpl.colors.LogNorm(), cmap=plt.cm.get_cmap('Spectral_r'))
cb = plt.colorbar()
cb.set_label('Number of molecules')
plt.clim(1, 100000)
plt.ylim((0.5, 1.02))
plt.xlim((0, 1))
plt.title("NPR heatmap")
plt.xlabel('npr1')
plt.ylabel('npr2')
# Out:
# 0         0.1073
# 1         0.2110
# 2         0.0931
# 3         0.1128
# 4         0.1677
#            ...
# 405514    0.2232
# 405515    0.6116
# 405516    0.2764
# 405517    0.2622
# 405518    0.2052
# Name: npr1, Length: 405519, dtype: float64
# Plotting...
# Text(0, 0.5, 'npr2')
